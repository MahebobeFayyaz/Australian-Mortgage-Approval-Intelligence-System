# %% [markdown]
# # ABS - Australian Bureau of Statistics
# ## Lending Indicators Data

# %% [markdown]
# ## Table 1.
# Households; Housing finance; Total dwellings; By property purpose; New loan commitments; Values

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

# %%
# Load CSV file
df_total_loans = pd.read_csv("../Datasets/df_total_loans.csv")
df_total_loans.head(5)
# Out:
#          date         segment            buyer_type  loan_count  \
# 0  2002-09-01        Investor                 Total         NaN
# 1  2002-09-01  Owner-occupier      First Home Buyer     24529.0
# 2  2002-09-01  Owner-occupier  Non-First Home Buyer     64722.0
# 3  2002-09-01  Owner-occupier                 Total     89705.0
# 4  2002-09-01           Total                 Total         NaN
#
#    loan_value_million
# 0             11009.5
# 1              4121.6
# 2             12468.5
# 3             16698.5
# 4             27708.0

# %%
df_total_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                465 non-null    object
#  1   segment             465 non-null    object
#  2   buyer_type          465 non-null    object
#  3   loan_count          329 non-null    float64
#  4   loan_value_million  465 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 18.3+ KB

# %%
# Value counts for segment
print("Segment value counts:")
print(df_total_loans["segment"].value_counts())

# Value counts for buyer_type
print("\nBuyer Type value counts:")
print(df_total_loans["buyer_type"].value_counts())
# Out:
# Segment value counts:
# segment
# Owner-occupier    279
# Investor           93
# Total              93
# Name: count, dtype: int64
#
# Buyer Type value counts:
# buyer_type
# Total                   279
# First Home Buyer         93
# Non-First Home Buyer     93
# Name: count, dtype: int64

# %%
df_total_loans.describe()
# Out:
#           loan_count  loan_value_million
# count     329.000000          465.000000
# mean    61650.173252        28141.192043
# std     31391.607683        18360.699880
# min     18264.000000         3845.500000
# 25%     30609.000000        15066.300000
# 50%     60407.000000        23852.300000
# 75%     82555.000000        37701.600000
# max    157887.000000        98005.100000

# %% [markdown]
# ##### Convert date to datetime

# %%
df_total_loans["date"] = pd.to_datetime(df_total_loans["date"])

# %%
df_total_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                465 non-null    datetime64[ns]
#  1   segment             465 non-null    object
#  2   buyer_type          465 non-null    object
#  3   loan_count          329 non-null    float64
#  4   loan_value_million  465 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 18.3+ KB

# %% [markdown]
# ##### Handling Missing Values

# %%
df_total_loans.isnull().sum()
# Out:
# date                    0
# segment                 0
# buyer_type              0
# loan_count            136
# loan_value_million      0
# dtype: int64

# %% [markdown]
# loan_count
#
# Non-null: 329 (~71%)
#
# Missing values: 136 (~29%)
#
# Reason for missing data:
#
# Loan counts are not reported for aggregated “Total” rows. This is a structural missingness, not a data quality issue

# %%
# Drop rows where both segment and buyer_type are "Total"
df_clean = df_total_loans[~((df_total_loans["segment"] == "Total") & 
                             (df_total_loans["buyer_type"] == "Total"))].copy()

# %%
df_clean.head(50)
# Out:
#          date         segment            buyer_type  loan_count  \
# 0  2002-09-01        Investor                 Total         NaN
# 1  2002-09-01  Owner-occupier      First Home Buyer     24529.0
# 2  2002-09-01  Owner-occupier  Non-First Home Buyer     64722.0
# 3  2002-09-01  Owner-occupier                 Total     89705.0
# 5  2002-12-01        Investor                 Total         NaN
# 6  2002-12-01  Owner-occupier      First Home Buyer     23090.0
# 7  2002-12-01  Owner-occupier  Non-First Home Buyer     65802.0
# 8  2002-12-01  Owner-occupier                 Total     88932.0
# 10 2003-03-01        Investor                 Total         NaN
# 11 2003-03-01  Owner-occupier      First Home Buyer     22989.0
# 12 2003-03-01  Owner-occupier  Non-First Home Buyer     70566.0
# 13 2003-03-01  Owner-occupier                 Total     93663.0
# 15 2003-06-01        Investor                 Total         NaN
# 16 2003-06-01  Owner-occupier      First Home Buyer     22351.0
# 17 2003-06-01  Owner-occupier  Non-First Home Buyer     73482.0
# 18 2003-06-01  Owner-occupier                 Total     95978.0
# 20 2003-09-01        Investor                 Total         NaN
# 21 2003-09-01  Owner-occupier      First Home Buyer     22181.0
# 22 2003-09-01  Owner-occupier  Non-First Home Buyer     76388.0
# 23 2003-09-01  Owner-occupier                 Total     98332.0
# 25 2003-12-01        Investor                 Total         NaN
# 26 2003-12-01  Owner-occupier      First Home Buyer     21147.0
# 27 2003-12-01  Owner-occupier  Non-First Home Buyer     73045.0
# 28 2003-12-01  Owner-occupier                 Total     94320.0
# 30 2004-03-01        Investor                 Total         NaN
# 31 2004-03-01  Owner-occupier      First Home Buyer     18264.0
# 32 2004-03-01  Owner-occupier  Non-First Home Buyer     64919.0
# 33 2004-03-01  Owner-occupier                 Total     83192.0
# 35 2004-06-01        Investor                 Total         NaN
# 36 2004-06-01  Owner-occupier      First Home Buyer     19342.0
# 37 2004-06-01  Owner-occupier  Non-First Home Buyer     61926.0
# 38 2004-06-01  Owner-occupier                 Total     81231.0
# 40 2004-09-01        Investor                 Total         NaN
# 41 2004-09-01  Owner-occupier      First Home Buyer     21670.0
# 42 2004-09-01  Owner-occupier  Non-First Home Buyer     61512.0
# 43 2004-09-01  Owner-occupier                 Total     83231.0
# 45 2004-12-01        Investor                 Total         NaN
# 46 2004-12-01  Owner-occupier      First Home Buyer     22716.0
# 47 2004-12-01  Owner-occupier  Non-First Home Buyer     63166.0
# 48 2004-12-01  Owner-occupier                 Total     85776.0
# 50 2005-03-01        Investor                 Total         NaN
# 51 2005-03-01  Owner-occupier      First Home Buyer     24097.0
# 52 2005-03-01  Owner-occupier  Non-First Home Buyer     65239.0
# 53 2005-03-01  Owner-occupier                 Total     89125.0
# 55 2005-06-01        Investor                 Total         NaN
# 56 2005-06-01  Owner-occupier      First Home Buyer     26157.0
# 57 2005-06-01  Owner-occupier  Non-First Home Buyer     65262.0
# 58 2005-06-01  Owner-occupier                 Total     91078.0
# 60 2005-09-01        Investor                 Total         NaN
# 61 2005-09-01  Owner-occupier      First Home Buyer     27210.0
#
#     loan_value_million
# 0              11009.5
# 1               4121.6
# 2              12468.5
# 3              16698.5
# 5              10978.6
# 6               4045.5
# 7              13125.4
# 8              17202.2
# 10             12179.5
# 11              4172.1
# 12             14410.9
# 13             18570.9
# 15             13117.8
# 16              4236.2
# 17             15685.6
# 18             20009.5
# 20             16164.3
# 21              4479.7
# 22             16899.5
# 23             21379.9
# 25             16277.6
# 26              4363.8
# 27             16515.9
# 28             20909.8
# 30             14225.0
# 31              3845.5
# 32             15169.4
# 33             18993.8
# 35             12936.5
# 36              4301.6
# 37             14984.0
# 38             19314.5
# 40             12627.6
# 41              4883.1
# 42             15000.8
# 43             19931.0
# 45             12980.0
# 46              5237.1
# 47             15606.2
# 48             20813.7
# 50             13937.1
# 51              5577.6
# 52             16360.7
# 53             21863.1
# 55             13059.4
# 56              6028.4
# 57             16304.4
# 58             22257.3
# 60             13035.1
# 61              6390.8
